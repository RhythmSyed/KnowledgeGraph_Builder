# %%
import spacy
import pandas as pd
from spacy import displacy
import en_core_web_lg
from pathlib import Path

# %%
#! python -m spacy download en_trf_bertbaseuncased_lg

# %%
nlp = en_core_web_lg.load()

# %% [markdown]
# # Parsing & Part-of-Speech Tags

# %% [markdown]
# <b>Text</b>: The original word text.<br>
# <b>Lemma</b>: The base form of the word.<br>
# <b>POS</b>: The simple UPOS part-of-speech tag.<br>
# <b>Tag</b>: The detailed part-of-speech tag.<br>
# <b>Dep</b>: Syntactic dependency, i.e. the relation between tokens.<br>
# <b>Shape</b>: The word shape – capitalization, punctuation, digits.<br>
# <b>is_alpha</b>: Is the token an alpha character?<br>
# <b>is_stop</b>: Is the token part of a stop list, i.e. the most common words of the language?<br>

# %%
doc = nlp('Darth Vader is also known by his birth name Anakin Skywalker.')
results = pd.DataFrame(columns=['Text', 'Lemma', 'POS', 'Tag', 'Dep', 'Shape', 'is_alpha', 'is_stop'])

for token in doc:  
    results = results.append({'Text':token.text, 'Lemma':token.lemma_, 'POS':token.pos_, 'Tag':token.tag_, 'Dep':token.dep_, 'Shape':token.shape_, 'is_alpha':token.is_alpha, 'is_stop':token.is_stop}, ignore_index=True)
results
# Out:
#          Text      Lemma    POS   Tag        Dep  Shape is_alpha is_stop
# 0       Darth      Darth  PROPN   NNP   compound  Xxxxx     True   False
# 1       Vader      Vader  PROPN   NNP  nsubjpass  Xxxxx     True   False
# 2          is         be    AUX   VBZ    auxpass     xx     True    True
# 3        also       also    ADV    RB     advmod   xxxx     True    True
# 4       known       know   VERB   VBN       ROOT   xxxx     True   False
# 5          by         by    ADP    IN       prep     xx     True    True
# 6         his     -PRON-    DET  PRP$       poss    xxx     True    True
# 7       birth      birth   NOUN    NN   compound   xxxx     True   False
# 8        name       name   NOUN    NN       pobj   xxxx     True    True
# 9      Anakin     Anakin  PROPN   NNP   compound  Xxxxx     True   False
# 10  Skywalker  Skywalker  PROPN   NNP      appos  Xxxxx     True   False
# 11          .          .  PUNCT     .      punct      .    False   False

# %%
svg = displacy.render(doc, style="dep",jupyter=True)
#output_path = Path("dep.svg")
#output_path.open("w", encoding="utf-8").write(svg)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fd1b5cf9b61c419eb1d3be5677387d66-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Darth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Vader</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">known</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">birth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">name</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Anakin</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Skywalker.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-1" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-2" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-5" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-6" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-7" stroke-width="2px" d="M945,264.5 C945,2.0 1450.0,2.0 1450.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,266.5 L1458.0,254.5 1442.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fd1b5cf9b61c419eb1d3be5677387d66-0-8" stroke-width="2px" d="M1645,264.5 C1645,177.0 1790.0,177.0 1790.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px

# %% [markdown]
# # Named Entities (NER)

# %% [markdown]
# <b>Text</b>: The original entity text.<br>
# <b>Start</b>: Index of start of entity in the Doc.<br>
# <b>End</b>: Index of end of entity in the Doc.<br>
# <b>Label</b>: Entity label, i.e. type.<br>

# %%
doc = nlp('Darth Vader is also known by his birth name Anakin Skywalker.')
results = pd.DataFrame(columns=['Text', 'Start', 'End', 'Label'])

for ent in doc.ents:  
    results = results.append({'Text':ent.text, 'Start':ent.start_char, 'End':ent.end_char, 'Label':ent.label_}, ignore_index=True)
results
# Out:
#                Text Start End   Label
# 0       Darth Vader     0  11  PERSON
# 1  Anakin Skywalker    44  60  PERSON

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Darth Vader
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is also known by his birth name
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anakin Skywalker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div></span>

# %% [markdown]
# # Larger Text Example

# %%
article = 'Darth Vader, also known by his birth name Anakin Skywalker, is a fictional character in the Star Wars franchise.123 Vader appears in the original film trilogy as a pivotal antagonist whose actions drive the plot, while his past as Anakin Skywalker and the story of his corruption are central to the narrative of the prequel trilogy., The character was created by George Lucas and has been portrayed by numerous actors. His appearances span the first six Star Wars films, as well as Rogue One, and his character is heavily referenced in Star Wars: The Force Awakens. He is also an important character in the Star Wars expanded universe of television series, video games, novels, literature and comic books. Originally a Jedi prophesied to bring balance to the Force, he falls to the dark side of the Force and serves the evil Galactic Empire at the right hand of his Sith master, Emperor Palpatine (also known as Darth Sidious).4 He is also the father of Luke Skywalker and Princess Leia Organa, secret husband of Padmé Amidala and grandfather of Kylo Ren., Darth Vader has become one of the most iconic villains in popular culture, and has been listed among the greatest villains and fictional characters ever.56 The American Film Institute listed him as the third greatest movie villain in cinema history on 100 Years... 100 Heroes and Villains, behind Hannibal Lecter and Norman Bates.7 However, other critics consider him a tragic hero, citing his original motivations for the greater good before his fall to the dark side.'
article
# Out:
# 'Darth Vader, also known by his birth name Anakin Skywalker, is a fictional character in the Star Wars franchise.123 Vader appears in the original film trilogy as a pivotal antagonist whose actions drive the plot, while his past as Anakin Skywalker and the story of his corruption are central to the narrative of the prequel trilogy., The character was created by George Lucas and has been portrayed by numerous actors. His appearances span the first six Star Wars films, as well as Rogue One, and his character is heavily referenced in Star Wars: The Force Awakens. He is also an important character in the Star Wars expanded universe of television series, video games, novels, literature and comic books. Originally a Jedi prophesied to bring balance to the Force, he falls to the dark side of the Force and serves the evil Galactic Empire at the right hand of his Sith master, Emperor Palpatine (also known as Darth Sidious).4 He is also the father of Luke Skywalker and Princess Leia Organa, secret husband of Padmé Amidala and grandfather of Kylo Ren., Darth Vader has become one of the most iconic villains in popular culture, and has been listed among the greatest villains and fictional characters ever.56 The American Film Institute listed him as the third greatest movie villain in cinema history on 100 Years... 100 Heroes and Villains, behind Hannibal Lecter and Norman Bates.7 However, other critics consider him a tragic hero, citing his original motivations for the greater good before his fall to the dark side.'

# %%
doc = nlp(article)
results = pd.DataFrame(columns=['Text', 'Lemma', 'POS', 'Tag', 'Dep', 'Shape', 'is_alpha', 'is_stop'])

for token in doc:  
    results = results.append({'Text':token.text, 'Lemma':token.lemma_, 'POS':token.pos_, 'Tag':token.tag_, 'Dep':token.dep_, 'Shape':token.shape_, 'is_alpha':token.is_alpha, 'is_stop':token.is_stop}, ignore_index=True)
results
# Out:
#       Text  Lemma    POS  Tag       Dep  Shape is_alpha is_stop
# 0    Darth  Darth  PROPN  NNP  compound  Xxxxx     True   False
# 1    Vader  Vader  PROPN  NNP     nsubj  Xxxxx     True   False
# 2        ,      ,  PUNCT    ,     punct      ,    False   False
# 3     also   also    ADV   RB    advmod   xxxx     True    True
# 4    known   know   VERB  VBN       acl   xxxx     True   False
# ..     ...    ...    ...  ...       ...    ...      ...     ...
# 277     to     to    ADP   IN      prep     xx     True    True
# 278    the    the    DET   DT       det    xxx     True    True
# 279   dark   dark    ADJ   JJ      amod   xxxx     True   False
# 280   side   side   NOUN   NN      pobj   xxxx     True    True
# 281      .      .  PUNCT    .     punct      .    False   False
#
# [282 rows x 8 columns]

# %%
#displacy.render(doc, style="dep", jupyter=True)

# %% [markdown]
# # Stanford Open Information Extraction using CoreNLP

# %% [markdown]
# https://nlp.stanford.edu/software/openie.html

# %% [markdown]
# Extracting {entity1, relation, entity2} triples:

# %%
from openie import StanfordOpenIE

# %%
with StanfordOpenIE() as client:
    text = 'Darth Vader is also known by his birth name Anakin Skywalker.'
    print('Text: %s.' % text)
    
    for triple in client.annotate(text):
        print(triple)
# Out:
# Text: Darth Vader is also known by his birth name Anakin Skywalker..
# Starting server with command: java -Xmx8G -cp /Users/rhythmsyed/stanfordnlp_resources/stanford-corenlp-full-2018-10-05/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-535e92b723cd4e6f.props -preload openie
# {'subject': 'Darth Vader', 'relation': 'is known by', 'object': 'his birth name Anakin Skywalker'}
# {'subject': 'Darth Vader', 'relation': 'is', 'object': 'also known'}
# {'subject': 'Darth Vader', 'relation': 'is', 'object': 'known'}
# {'subject': 'Darth Vader', 'relation': 'is also known by', 'object': 'his birth name Anakin Skywalker'}

# %% [markdown]
# Trying longer document text:

# %%
triples = []
with StanfordOpenIE() as client:
    print('Text: %s.' % article)
    for triple in client.annotate(article):
        triples.append(triple)
# Out:
# Text: Darth Vader, also known by his birth name Anakin Skywalker, is a fictional character in the Star Wars franchise.123 Vader appears in the original film trilogy as a pivotal antagonist whose actions drive the plot, while his past as Anakin Skywalker and the story of his corruption are central to the narrative of the prequel trilogy., The character was created by George Lucas and has been portrayed by numerous actors. His appearances span the first six Star Wars films, as well as Rogue One, and his character is heavily referenced in Star Wars: The Force Awakens. He is also an important character in the Star Wars expanded universe of television series, video games, novels, literature and comic books. Originally a Jedi prophesied to bring balance to the Force, he falls to the dark side of the Force and serves the evil Galactic Empire at the right hand of his Sith master, Emperor Palpatine (also known as Darth Sidious).4 He is also the father of Luke Skywalker and Princess Leia Organa, secret husband of Padmé Amidala and grandfather of Kylo Ren., Darth Vader has become one of the most iconic villains in popular culture, and has been listed among the greatest villains and fictional characters ever.56 The American Film Institute listed him as the third greatest movie villain in cinema history on 100 Years... 100 Heroes and Villains, behind Hannibal Lecter and Norman Bates.7 However, other critics consider him a tragic hero, citing his original motivations for the greater good before his fall to the dark side..
# Starting server with command: java -Xmx8G -cp /Users/rhythmsyed/stanfordnlp_resources/stanford-corenlp-full-2018-10-05/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-52fa903739d94899.props -preload openie

# %%
triples[:3]
# Out:
# [{'subject': 'Darth Vader', 'relation': 'is', 'object': 'fictional character'},
#  {'subject': 'fictional character',
#   'relation': 'is in',
#   'object': 'Star Wars franchise'},
#  {'subject': 'Vader', 'relation': 'appears in', 'object': 'film trilogy'}]

# %%
print(f'Number of Entity-Relation triples: {len(triples)}')
# Out:
# Number of Entity-Relation triples: 89

# %% [markdown]
# # Encoding using BERT

# %% [markdown]
# https://explosion.ai/blog/spacy-transformers

# %%
import spacy
import en_trf_bertbaseuncased_lg

nlp = en_trf_bertbaseuncased_lg.load()

# %% [markdown]
# Use word-level embeddings from BERT to add context to tokens:

# %%
apple1 = nlp("Apple shares rose on the news.")
apple2 = nlp("Apple sold fewer iPhones this quarter.")
apple3 = nlp("Apple pie is delicious.")

# %%
print(apple1[0].similarity(apple2[0]))
print(apple1[0].similarity(apple3[0]))
# Out:
# 0.7342852
# 0.433657

# %%
article_enc = nlp(article)
vader_example = nlp('A popular dialogue from Darth Vader is, Luke I am your father.')

# %%
article_enc.similarity(vader_example)
# Out:
# 0.7885571923391387

# %%
test = ' '.join(x for x in triples[0].values())
article_enc.similarity(nlp(test))
# Out:
# 0.7175568134427756

# %% [markdown]
# Check cosine similarity of each triple and eliminate based on threshold:

# %%
triples_filtered = []
threshold = 0.50
for triple in triples:
    statement = ' '.join(x for x in triple.values())
    similarity = article_enc.similarity(nlp(statement))
    if similarity > threshold:
        triples_filtered.append(triple)
    print(triple, similarity)
    print()
# Out:
# {'subject': 'Darth Vader', 'relation': 'is', 'object': 'fictional character'} 0.7175568134427756
#
# {'subject': 'fictional character', 'relation': 'is in', 'object': 'Star Wars franchise'} 0.6769007695427789
#
# {'subject': 'Vader', 'relation': 'appears in', 'object': 'film trilogy'} 0.6853778819379464
#
# {'subject': 'character', 'relation': 'was', 'object': 'created'} 0.4450941733865092
#
# {'subject': 'Vader', 'relation': 'appears as', 'object': 'pivotal antagonist'} 0.6134172752533587
#
# {'subject': '.123 Vader', 'relation': 'appears in', 'object': 'original film trilogy'} 0.7367025108877702
#
# {'subject': '.123 Vader', 'relation': 'appears as', 'object': 'pivotal antagonist'} 0.6415943665749564
#
# {'subject': 'character', 'relation': 'been portrayed by', 'object': 'numerous actors'} 0.5961205702483965
#
# {'subject': 'Darth Vader', 'relation': 'also known by', 'object': 'his birth name Anakin Skywalker'} 0.7996625754653531
#
# {'subject': 'Vader', 'relation': 'appears as', 'object': 'antagonist'} 0.6105470371172497
#
# {'subject': 'his past', 'relation': 'are central to', 'object': 'narrative of prequel trilogy.'} 0.622305413638658
#
# {'subject': 'character', 'relation': 'been portrayed by', 'object': 'actors'} 0.5213287158529105
#
# {'subject': '.123 Vader', 'relation': 'appears in', 'object': 'film trilogy'} 0.707011631591966
#
# {'subject': 'Vader', 'relation': 'appears in', 'object': 'original film trilogy'} 0.7087003271776108
#
# {'subject': 'Darth Vader', 'relation': 'known by', 'object': 'his birth name Anakin Skywalker'} 0.7840042915395398
#
# {'subject': 'Darth Vader', 'relation': 'is fictional character in', 'object': 'Star Wars franchise'} 0.7916756945164675
#
# {'subject': 'character', 'relation': 'been', 'object': 'portrayed'} 0.4257191628523221
#
# {'subject': 'his past', 'relation': 'are central to', 'object': 'narrative'} 0.5440775151569965
#
# {'subject': 'character', 'relation': 'was created by', 'object': 'George Lucas'} 0.5991293606397613
#
# {'subject': 'actions', 'relation': 'drive', 'object': 'plot'} 0.4023492498973969
#
# {'subject': '.123 Vader', 'relation': 'appears as', 'object': 'antagonist'} 0.6564969894474385
#
# {'subject': 'his past', 'relation': 'are', 'object': 'central'} 0.44455969125208306
#
# {'subject': 'his character', 'relation': 'is heavily referenced in', 'object': 'Star Wars'} 0.8264422267090684
#
# {'subject': 'His appearances', 'relation': 'span', 'object': 'six Star Wars films'} 0.7368131506239786
#
# {'subject': 'His appearances', 'relation': 'span', 'object': 'Rogue One'} 0.5885746751510569
#
# {'subject': 'his character', 'relation': 'is referenced in', 'object': 'Star Wars'} 0.8140245172330541
#
# {'subject': 'his character', 'relation': 'is', 'object': 'heavily referenced'} 0.587891515722611
#
# {'subject': 'His appearances', 'relation': 'span', 'object': 'first six Star Wars films'} 0.738563717844696
#
# {'subject': 'his character', 'relation': 'is', 'object': 'referenced'} 0.495400477403633
#
# {'subject': 'He', 'relation': 'is also character in', 'object': 'Star Wars'} 0.7497793423410709
#
# {'subject': 'important character', 'relation': 'is in', 'object': 'Star Wars'} 0.6620177595523723
#
# {'subject': 'He', 'relation': 'is', 'object': 'important'} 0.42785696335459694
#
# {'subject': 'He', 'relation': 'is', 'object': 'also character'} 0.460482901774895
#
# {'subject': 'He', 'relation': 'is', 'object': 'character'} 0.397587340631764
#
# {'subject': 'He', 'relation': 'is important character in', 'object': 'Star Wars'} 0.740859398443302
#
# {'subject': 'He', 'relation': 'is character in', 'object': 'Star Wars'} 0.7120834775635374
#
# {'subject': 'He', 'relation': 'is', 'object': 'important character'} 0.45404559298800296
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations for good before', 'object': 'his fall side'} 0.7172256946490423
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations before', 'object': 'his fall dark side'} 0.7303567739911757
#
# {'subject': '100 Heroes Villains', 'relation': 'citing', 'object': 'his motivations for good'} 0.6938695033331453
#
# {'subject': 'Jedi', 'relation': 'bring', 'object': 'balance'} 0.4695092180561265
#
# {'subject': 'third greatest movie villain', 'relation': 'is in', 'object': 'cinema history'} 0.6256695655022168
#
# {'subject': 'Jedi', 'relation': 'bring balance to', 'object': 'Force'} 0.5263622841269582
#
# {'subject': '100 Heroes Villains', 'relation': 'citing', 'object': 'his motivations'} 0.6802943371828266
#
# {'subject': '100 Heroes Villains', 'relation': 'citing', 'object': 'his original motivations for greater good'} 0.7229701114137119
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations for greater good before', 'object': 'his fall side'} 0.7365658345360001
#
# {'subject': 'he', 'relation': 'been listed among', 'object': 'greatest villains'} 0.5798152783136657
#
# {'subject': 'critics', 'relation': 'consider', 'object': 'him tragic hero'} 0.5226124328656636
#
# {'subject': '100 Heroes Villains', 'relation': 'citing', 'object': 'his motivations for greater good'} 0.7188038191596414
#
# {'subject': 'He', 'relation': 'is also father of', 'object': 'Luke Skywalker'} 0.7115160521613202
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations for good before', 'object': 'his fall'} 0.7358218953565958
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations for greater good before', 'object': 'his fall'} 0.757846016234443
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations before', 'object': 'his fall side'} 0.7110516591656186
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations for good before', 'object': 'his fall'} 0.7360763219102716
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations before', 'object': 'his fall'} 0.7274654717040453
#
# {'subject': 'He', 'relation': 'is', 'object': 'also father'} 0.38506211267400275
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'movie villain'} 0.7054899846559
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter on', 'object': '100 Years'} 0.7069780679645201
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'third greatest movie villain'} 0.7543858050244615
#
# {'subject': 'American Film Institute', 'relation': 'listed', 'object': 'Hannibal Lecter'} 0.6981254149759445
#
# {'subject': 'He', 'relation': 'is father of', 'object': 'Luke Skywalker'} 0.6810931400794982
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'movie villain in cinema history'} 0.7778991625688416
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'third movie villain in cinema history'} 0.7894847554575176
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'third greatest movie villain in cinema history'} 0.8029750701093411
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations for good before', 'object': 'his fall dark side'} 0.7281180135789053
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations for good before', 'object': 'his fall side'} 0.7184728697994206
#
# {'subject': 'he', 'relation': 'been listed among', 'object': 'villains'} 0.46128953324010163
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'greatest movie villain in cinema history'} 0.7917110263370477
#
# {'subject': 'American Film Institute', 'relation': 'listed', 'object': '100 Heroes'} 0.6051722978518851
#
# {'subject': 'other critics', 'relation': 'consider', 'object': 'him tragic hero'} 0.5476185253392566
#
# {'subject': 'American Film Institute', 'relation': 'listed', 'object': 'Hannibal Lecter However'} 0.6808957915474911
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'third movie villain'} 0.705508214422553
#
# {'subject': 'his', 'relation': 'master', 'object': 'Emperor Palpatine .4'} 0.6026036083177677
#
# {'subject': 'he', 'relation': 'been', 'object': 'listed'} 0.37129967705055106
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations for greater good before', 'object': 'his fall'} 0.7568537277583156
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations for greater good before', 'object': 'his fall side'} 0.7441029364951708
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations before', 'object': 'his fall side'} 0.716831684026373
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations before', 'object': 'his fall dark side'} 0.732535583795387
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations for good before', 'object': 'his fall dark side'} 0.7323033631627923
#
# {'subject': 'He', 'relation': 'is', 'object': 'father'} 0.3904485663537688
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations for greater good before', 'object': 'his fall dark side'} 0.7531449367336372
#
# {'subject': 'American Film Institute', 'relation': 'listed Hannibal Lecter as', 'object': 'greatest movie villain'} 0.7411301725763856
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his original motivations before', 'object': 'his fall'} 0.73012780747217
#
# {'subject': '100 Heroes Villains', 'relation': 'citing his motivations for greater good before', 'object': 'his fall dark side'} 0.7514851850304176
#
# {'subject': 'iconic villains', 'relation': 'is in', 'object': 'popular culture'} 0.6388469093958004
#
# {'subject': 'critics', 'relation': 'consider', 'object': 'him hero'} 0.47798322891242234
#
# {'subject': '100 Heroes Villains', 'relation': 'citing', 'object': 'his original motivations for good'} 0.6926821363741724
#
# {'subject': '100 Heroes Villains', 'relation': 'citing', 'object': 'his original motivations'} 0.6863605264439058
#
# {'subject': 'other critics', 'relation': 'consider', 'object': 'him hero'} 0.49733056015032584

# %%
print(len(triples), len(triples_filtered))
# Out:
# 89 73

# %% [markdown]
# # KG Creation & Exploration

# %%
import rdflib

# %%
starwars_graph = rdflib.Graph()

# %%
for triple in triples_filtered:
    starwars_graph.add((
        rdflib.Literal(triple['subject'], datatype=rdflib.namespace.XSD.string),
        rdflib.Literal(triple['relation'], datatype=rdflib.namespace.XSD.string),
        rdflib.Literal(triple['object'], datatype=rdflib.namespace.XSD.string)
    ))

# %%
for s, p, o in starwars_graph:
    print(s, '->', p, '->', o)
# Out:
# 100 Heroes Villains -> citing his original motivations for good before -> his fall side
# American Film Institute -> listed -> 100 Heroes
# American Film Institute -> listed Hannibal Lecter as -> greatest movie villain
# 100 Heroes Villains -> citing -> his motivations for greater good
# other critics -> consider -> him tragic hero
# 100 Heroes Villains -> citing his original motivations before -> his fall
# fictional character -> is in -> Star Wars franchise
# his character -> is referenced in -> Star Wars
# Vader -> appears as -> pivotal antagonist
# he -> been listed among -> greatest villains
# character -> been portrayed by -> numerous actors
# iconic villains -> is in -> popular culture
# 100 Heroes Villains -> citing his original motivations for greater good before -> his fall side
# .123 Vader -> appears in -> film trilogy
# 100 Heroes Villains -> citing his motivations for good before -> his fall dark side
# American Film Institute -> listed -> Hannibal Lecter However
# third greatest movie villain -> is in -> cinema history
# American Film Institute -> listed Hannibal Lecter as -> third greatest movie villain
# his character -> is heavily referenced in -> Star Wars
# He -> is character in -> Star Wars
# American Film Institute -> listed Hannibal Lecter on -> 100 Years
# character -> was created by -> George Lucas
# his -> master -> Emperor Palpatine .4
# 100 Heroes Villains -> citing his original motivations before -> his fall dark side
# His appearances -> span -> first six Star Wars films
# 100 Heroes Villains -> citing -> his original motivations for greater good
# His appearances -> span -> six Star Wars films
# 100 Heroes Villains -> citing his motivations before -> his fall
# his character -> is -> heavily referenced
# 100 Heroes Villains -> citing his motivations for greater good before -> his fall side
# 100 Heroes Villains -> citing his motivations for good before -> his fall side
# American Film Institute -> listed Hannibal Lecter as -> greatest movie villain in cinema history
# Vader -> appears as -> antagonist
# American Film Institute -> listed -> Hannibal Lecter
# Vader -> appears in -> film trilogy
# 100 Heroes Villains -> citing his original motivations before -> his fall side
# 100 Heroes Villains -> citing his original motivations for good before -> his fall
# .123 Vader -> appears in -> original film trilogy
# critics -> consider -> him tragic hero
# Darth Vader -> is fictional character in -> Star Wars franchise
# American Film Institute -> listed Hannibal Lecter as -> third movie villain in cinema history
# his past -> are central to -> narrative
# Jedi -> bring balance to -> Force
# American Film Institute -> listed Hannibal Lecter as -> third movie villain
# 100 Heroes Villains -> citing his motivations before -> his fall dark side
# 100 Heroes Villains -> citing his motivations for greater good before -> his fall dark side
# character -> been portrayed by -> actors
# 100 Heroes Villains -> citing his original motivations for greater good before -> his fall
# .123 Vader -> appears as -> antagonist
# Darth Vader -> is -> fictional character
# American Film Institute -> listed Hannibal Lecter as -> movie villain in cinema history
# American Film Institute -> listed Hannibal Lecter as -> third greatest movie villain in cinema history
# He -> is important character in -> Star Wars
# He -> is also father of -> Luke Skywalker
# 100 Heroes Villains -> citing his original motivations for good before -> his fall dark side
# 100 Heroes Villains -> citing -> his motivations
# Darth Vader -> also known by -> his birth name Anakin Skywalker
# His appearances -> span -> Rogue One
# He -> is father of -> Luke Skywalker
# 100 Heroes Villains -> citing his motivations before -> his fall side
# .123 Vader -> appears as -> pivotal antagonist
# Vader -> appears in -> original film trilogy
# his past -> are central to -> narrative of prequel trilogy.
# 100 Heroes Villains -> citing -> his original motivations for good
# 100 Heroes Villains -> citing his motivations for greater good before -> his fall
# American Film Institute -> listed Hannibal Lecter as -> movie villain
# 100 Heroes Villains -> citing his motivations for good before -> his fall
# 100 Heroes Villains -> citing -> his original motivations
# 100 Heroes Villains -> citing -> his motivations for good
# Darth Vader -> known by -> his birth name Anakin Skywalker
# 100 Heroes Villains -> citing his original motivations for greater good before -> his fall dark side
# important character -> is in -> Star Wars
# He -> is also character in -> Star Wars

# %% [markdown]
# Sample queries:

# %%
query_str = """
    SELECT ?s ?p ?o
    WHERE {   
        # ?s ?p ?o.
        FILTER(?s='Darth Vader')
    }
"""

res = starwars_graph.query(query_str)
for s,p,o in res:
    print(s, '->', p, '->', o)
# Out:
# Darth Vader -> is fictional character in -> Star Wars franchise
# Darth Vader -> is -> fictional character
# Darth Vader -> also known by -> his birth name Anakin Skywalker
# Darth Vader -> known by -> his birth name Anakin Skywalker

# %%
query_str = """
    SELECT ?s ?p ?o
    WHERE {   
        # ?s ?p ?o.
        FILTER(?s='Vader')
    }
"""

res = starwars_graph.query(query_str)
for s,p,o in res:
    print(s, '->', p, '->', o)
# Out:
# Vader -> appears as -> pivotal antagonist
# Vader -> appears as -> antagonist
# Vader -> appears in -> film trilogy
# Vader -> appears in -> original film trilogy

# %%
query_str = """
    SELECT ?s ?p ?o
    WHERE {   
        # ?s ?p ?o.
        FILTER(?s='He')
    }
"""
res = starwars_graph.query(query_str)

for s,p,o in res:
    print(s, '->', p, '->', o)
# Out:
# He -> is character in -> Star Wars
# He -> is important character in -> Star Wars
# He -> is also father of -> Luke Skywalker
# He -> is father of -> Luke Skywalker
# He -> is also character in -> Star Wars

# %% [markdown]
# ### TODO: Need to "contexualize" key entities that group together "He" and "Darth Vader" for example

# %% [markdown]
# # starwars.ttl Exploration

# %%
graph = rdflib.Graph()
graph.parse('../data/starwars.ttl', format='turtle')
# Out:
# <Graph identifier=Na5101f4fba1e42979f44bfe9db4956bc (<class 'rdflib.graph.Graph'>)>

# %%
for s,p,o in graph:
    print(s, '->', p, '->', o)
# Out:
# https://swapi.co/resource/starship/61 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 2000
# https://swapi.co/resource/planet/41 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/starship/17 -> https://swapi.co/vocabulary/consumables -> 6 months
# https://swapi.co/resource/human/25 -> https://swapi.co/vocabulary/skinColor -> dark
# https://swapi.co/resource/planet/31 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/starship/47 -> https://swapi.co/vocabulary/passengers -> 30000
# https://swapi.co/resource/starship/17 -> https://swapi.co/vocabulary/crew -> 6
# https://swapi.co/resource/vehicle/16 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Vehicle
# https://swapi.co/resource/human/51 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/vehicle/18 -> https://swapi.co/vocabulary/vehicleClass -> assault walker
# https://swapi.co/resource/tholothian/55 -> https://swapi.co/vocabulary/gender -> female
# https://swapi.co/resource/planet/8 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/gungan/37
# https://swapi.co/resource/trandoshan/24 -> https://swapi.co/vocabulary/mass -> 113.0
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/60
# https://swapi.co/resource/planet/44 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/nautolan/53
# https://swapi.co/resource/droid/23 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Droid
# https://swapi.co/resource/starship/22 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/droid/2 -> https://swapi.co/vocabulary/birthYear -> 112BBY
# https://swapi.co/resource/cerean/52 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/35
# https://swapi.co/resource/starship/3 -> https://swapi.co/vocabulary/model -> Imperial I-class Star Destroyer
# https://swapi.co/vocabulary/Togruta -> https://swapi.co/vocabulary/eyeColor -> blue
# https://swapi.co/resource/planet/12 -> http://www.w3.org/2000/01/rdf-schema#label -> Utapau
# https://swapi.co/vocabulary/Togruta -> https://swapi.co/vocabulary/eyeColor -> orange
# https://swapi.co/vocabulary/Toydarian -> https://swapi.co/vocabulary/skinColor -> grey
# https://swapi.co/vocabulary/Wookiee -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/wookiee/80
# https://swapi.co/resource/planet/56 -> http://www.w3.org/2000/01/rdf-schema#label -> Skako
# https://swapi.co/resource/keldor/58 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/kaleesh/79 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/vehicle/72 -> https://swapi.co/vocabulary/costInCredits -> 49000
# https://swapi.co/resource/human/68 -> https://swapi.co/vocabulary/birthYear -> 67BBY
# https://swapi.co/resource/human/10 -> http://www.w3.org/2000/01/rdf-schema#label -> Obi-Wan Kenobi
# https://swapi.co/resource/human/10 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/4
# https://swapi.co/resource/planet/40 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/human/14 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/moncalamari/27 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/31
# https://swapi.co/resource/droid/3 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/7
# https://swapi.co/resource/planet/1 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/nautolan/53 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/film/1 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/2
# https://swapi.co/resource/human/43 -> https://swapi.co/vocabulary/height -> 163.0
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/68
# https://swapi.co/resource/planet/33 -> https://swapi.co/vocabulary/orbitalPeriod -> 263
# https://swapi.co/resource/planet/11 -> https://swapi.co/vocabulary/gravity -> 0.9 standard
# https://swapi.co/resource/planet/2 -> https://swapi.co/vocabulary/orbitalPeriod -> 364
# https://swapi.co/resource/vehicle/37 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/vehicle/44 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/planet/14 -> https://swapi.co/vocabulary/diameter -> 12765
# https://swapi.co/vocabulary/Nautolan -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/nautolan/53
# https://swapi.co/resource/human/7 -> https://swapi.co/vocabulary/birthYear -> 47BBY
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/74
# https://swapi.co/resource/human/35 -> https://swapi.co/vocabulary/mass -> 45.0
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/droid/3
# https://swapi.co/resource/film/2 -> https://swapi.co/vocabulary/episodeId -> 5
# https://swapi.co/resource/human/10 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/cerean/52 -> https://swapi.co/vocabulary/birthYear -> 92BBY
# https://swapi.co/resource/starship/66 -> https://swapi.co/vocabulary/length -> 14.5
# https://swapi.co/resource/planet/7 -> https://swapi.co/vocabulary/diameter -> 4900
# https://swapi.co/resource/neimodian/33 -> https://swapi.co/vocabulary/height -> 191.0
# https://swapi.co/resource/planet/30 -> https://swapi.co/vocabulary/diameter -> 0
# https://swapi.co/resource/vulptereen/48 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/vehicle/18 -> https://swapi.co/vocabulary/crew -> 5
# https://swapi.co/vocabulary/Yodasspecies -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/resource/human/69 -> https://swapi.co/vocabulary/desc -> Jango Fett is a fictional character in the Star Wars franchise, created by George Lucas. He made his debut in the 2002 film Star Wars: Episode II – Attack of the Clones, where he was portrayed by actor Temuera Morrison., In the context of the Star Wars universe, Jango Fett was regarded as the best mercenary in the galaxy during the final years of the Republic. A naturally skilled warrior, he was eventually chosen to serve as the genetic template for the Clone Army of the Galactic Republic. These clone soldiers were genetically modified to be predisposed toward unquestioning obedience to the chain of command, unlike their highly independent progenitor. Jango was also the "father" of unaltered clone Boba Fett, which he requested as part of his contract with the Kaminoans.
# https://swapi.co/resource/droid/3 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/keldor/58
# https://swapi.co/resource/human/35 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/8
# https://swapi.co/resource/starship/47 -> http://www.w3.org/2000/01/rdf-schema#label -> AA-9 Coruscant freighter
# https://swapi.co/resource/vehicle/53 -> https://swapi.co/vocabulary/crew -> 6
# https://swapi.co/vocabulary/Umbaran -> https://swapi.co/vocabulary/language -> Umbaran
# https://swapi.co/resource/vehicle/30 -> https://swapi.co/vocabulary/vehicleClass -> speeder
# https://swapi.co/resource/cerean/52 -> https://swapi.co/vocabulary/skinColor -> pale
# https://swapi.co/resource/yodasspecies/20 -> https://swapi.co/vocabulary/hairColor -> white
# https://swapi.co/resource/toong/50 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/starship/32 -> https://swapi.co/vocabulary/length -> 3170.0
# https://swapi.co/resource/nautolan/53 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/44
# https://swapi.co/resource/starship/13 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/1
# https://swapi.co/resource/human/81 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/1
# https://swapi.co/vocabulary/Quermian -> https://swapi.co/vocabulary/language -> Quermian
# https://swapi.co/resource/film/1 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/hutt/16
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/21
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/hairColor -> red
# https://swapi.co/resource/starship/2 -> http://www.w3.org/2000/01/rdf-schema#label -> CR90 corvette
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/neimodian/33
# https://swapi.co/resource/planet/9 -> https://swapi.co/vocabulary/desc -> "Coruscant /ˈkɒrəsɑːnt/2 is a planet in the fictional Star Wars universe. It first appeared onscreen in the 1997 Special Edition of Return of the Jedi, but was first mentioned in Timothy Zahns 1991 novel Heir to the Empire. A city occupying an entire planet, it was renamed Imperial Center during the reign of the Galactic Empire (as depicted in the original films) and Yuuzhantar during the Yuuzhan Vong invasion (as depicted in the New Jedi Order novel series). The demonym and adjective form of the planet name is Coruscanti.", "Coruscant is, at various times, the capital of the Old Republic, the Galactic Empire, the New Republic, the Yuuzhan Vong Empire and the Galactic Alliance. Not only is Coruscant central to all these governing bodies, it is the navigational center of the galaxy, given that its hyperspace coordinates are (0,0,0). Due to its location and large population, roughly 2 trillion sentients, the galaxys main trade routes — Perlemian Trade Route, Hydian Way, Corellian Run and Corellian Trade Spine — go through Coruscant, making it the richest and most influential world in the Star Wars galaxy. Coruscant is the sixth planet out of 11 planets in the Coruscant solar system, and has four moons; Centax-1, Centax-2, Centax-3, and Hesperidium.", The Galactic Standard Calendar was the standard measurement of time in the Star Wars galaxy. It centered on the Coruscant tropical year. The Coruscant solar cycle was 368 days long; with a day consisting of 360 NET degrees (or 24 standard hours).3 Numerous epochs were used to determine calendar eras. The most recent of these calendar eras used the Battle of Yavin (i.e. the destruction of the first Death Star) as its epoch, or "year zero": BBY (Before the Battle of Yavin), and ABY (After the Battle of Yavin).4 The earliest date in the Star Wars expanded universe as a whole is 13,000,000,000 BBY, which serves as the year the universe was created.
# https://swapi.co/vocabulary/Kaminoan -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Species
# https://swapi.co/resource/planet/36 -> https://swapi.co/vocabulary/climate -> temperate
# https://swapi.co/resource/planet/33 -> https://swapi.co/vocabulary/climate -> superheated
# https://swapi.co/resource/starship/13 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/starship/63 -> https://swapi.co/vocabulary/manufacturer -> Kuat Drive Yards, Allanteen Six shipyards
# https://swapi.co/resource/vehicle/50 -> https://swapi.co/vocabulary/manufacturer -> Rothana Heavy Engineering
# https://swapi.co/resource/mirialan/65 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Mirialan
# https://swapi.co/resource/moncalamari/27 -> https://swapi.co/vocabulary/height -> 180.0
# https://swapi.co/resource/starship/74 -> https://swapi.co/vocabulary/starshipClass -> starfighter
# https://swapi.co/resource/vehicle/70 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/vehicle/18 -> https://swapi.co/vocabulary/manufacturer -> Kuat Drive Yards, Imperial Department of Military Research
# https://swapi.co/resource/neimodian/33 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/starship/2 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/4
# https://swapi.co/vocabulary/Rodian -> http://www.w3.org/2000/01/rdf-schema#label -> Rodian
# https://swapi.co/resource/vehicle/37 -> https://swapi.co/vocabulary/consumables -> 1 day
# https://swapi.co/vocabulary/Yodasspecies -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Species
# https://swapi.co/resource/planet/14 -> https://swapi.co/vocabulary/climate -> tropical
# https://swapi.co/resource/gungan/37 -> https://swapi.co/vocabulary/mass -> 82.0
# https://swapi.co/resource/vehicle/45 -> https://swapi.co/vocabulary/passengers -> 1
# https://swapi.co/resource/umbaran/82 -> https://swapi.co/vocabulary/eyeColor -> white
# https://swapi.co/resource/yodasspecies/20 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/vehicle/50 -> https://swapi.co/vocabulary/crew -> 6
# https://swapi.co/resource/hutt/16 -> http://www.w3.org/2000/01/rdf-schema#label -> Jabba Desilijic Tiure
# https://swapi.co/resource/human/62 -> https://swapi.co/vocabulary/hairColor -> brown
# https://swapi.co/resource/starship/40 -> https://swapi.co/vocabulary/model -> J-type 327 Nubian royal starship
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/planet -> https://swapi.co/resource/planet/1
# https://swapi.co/resource/planet/19 -> https://swapi.co/vocabulary/population -> 1400000000
# https://swapi.co/resource/planet/1 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/droid/2
# https://swapi.co/resource/vehicle/73 -> https://swapi.co/vocabulary/consumables -> none
# https://swapi.co/resource/vehicle/34 -> https://swapi.co/vocabulary/costInCredits -> 138000
# https://swapi.co/resource/starship/39 -> https://swapi.co/vocabulary/cargoCapacity -> 65
# https://swapi.co/resource/planet/50 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/starship/32 -> https://swapi.co/vocabulary/manufacturer -> Hoersch-Kessel Drive, Inc.
# https://swapi.co/resource/starship/77 -> https://swapi.co/vocabulary/manufacturer -> Incom
# https://swapi.co/vocabulary/Droid -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/droid/8
# https://swapi.co/vocabulary/Cerean -> https://swapi.co/vocabulary/hairColor -> white
# https://swapi.co/resource/droid/3 -> https://swapi.co/vocabulary/eyeColor -> red
# https://swapi.co/resource/droid/3 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/4
# https://swapi.co/resource/planet/1 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/human/4
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/29
# https://swapi.co/resource/vehicle/76 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/human/4 -> https://swapi.co/vocabulary/birthYear -> 41.9BBY
# https://swapi.co/resource/human/6 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/human/88 -> https://swapi.co/vocabulary/desc -> "Captain Phasma is a fictional character in the Star Wars franchise, portrayed by Gwendoline Christie. Introduced in Star Wars: The Force Awakens (2015), the first film in the Star Wars sequel trilogy, Phasma is the commander of the First Orders force of stormtroopers. Christie confirmed that the character would reappear in the next of the trilogys films, Star Wars: The Last Jedi. The character also made an additional appearance in Before the Awakening, an anthology book set before the events of The Force Awakens.", "J. J. Abrams created Phasma from an armor design originally developed for Kylo Ren and named her after the 1979 horror film Phantasm. The character was originally conceived as male before being changed to female. Phasma appeared prominently in promotion and marketing for The Force Awakens, but the characters ultimately minor role in the film was the subject of criticism. Nonetheless, merchandise featuring the character found success and her figure was the bestselling of all Force Awakens action figures on Amazon.co.uk.3"
# https://swapi.co/resource/human/29 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/vehicle/45 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/rodian/15 -> https://swapi.co/vocabulary/birthYear -> 44BBY
# https://swapi.co/vocabulary/Neimodian -> https://swapi.co/vocabulary/language -> Neimoidia
# https://swapi.co/resource/starship/11 -> http://www.w3.org/2000/01/rdf-schema#label -> Y-wing
# https://swapi.co/resource/vehicle/24 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 100
# https://swapi.co/vocabulary/Rodian -> https://swapi.co/vocabulary/eyeColor -> black
# https://swapi.co/resource/planet/59 -> https://swapi.co/vocabulary/population -> 4000000000
# https://swapi.co/resource/vehicle/38 -> https://swapi.co/vocabulary/crew -> 1
# https://swapi.co/resource/starship/9 -> https://swapi.co/vocabulary/crew -> 342953
# https://swapi.co/resource/planet/8 -> https://swapi.co/vocabulary/rotationPeriod -> 26
# https://swapi.co/resource/pauan/83 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/kaleesh/79 -> https://swapi.co/vocabulary/hairColor -> none
# https://swapi.co/resource/vehicle/76 -> https://swapi.co/vocabulary/costInCredits -> 40000
# https://swapi.co/resource/starship/40 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/droid/3 -> https://swapi.co/vocabulary/height -> 96.0
# https://swapi.co/resource/starship/15 -> https://swapi.co/vocabulary/manufacturer -> Kuat Drive Yards, Fondor Shipyards
# https://swapi.co/vocabulary/Dug -> https://swapi.co/vocabulary/planet -> https://swapi.co/resource/planet/35
# https://swapi.co/resource/vehicle/30 -> https://swapi.co/vocabulary/consumables -> 1 day
# https://swapi.co/resource/planet/3 -> https://swapi.co/vocabulary/rotationPeriod -> 24
# https://swapi.co/resource/wookiee/80 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/vehicle/54 -> https://swapi.co/vocabulary/vehicleClass -> walker
# https://swapi.co/resource/starship/32 -> https://swapi.co/vocabulary/consumables -> 500 days
# https://swapi.co/resource/vehicle/25 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/planet/12 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/starship/48 -> https://swapi.co/vocabulary/manufacturer -> Kuat Systems Engineering
# https://swapi.co/resource/zabrak/54 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Zabrak
# https://swapi.co/vocabulary/Gungan -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/gungan/36
# https://swapi.co/resource/human/25 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/10
# https://swapi.co/resource/planet/18 -> https://swapi.co/vocabulary/gravity -> 1 standard
# https://swapi.co/vocabulary/Muun -> https://swapi.co/vocabulary/skinColor -> grey
# https://swapi.co/resource/planet/33 -> http://www.w3.org/2000/01/rdf-schema#label -> Sullust
# https://swapi.co/resource/planet/44 -> https://swapi.co/vocabulary/climate -> tropical, temperate
# https://swapi.co/resource/vehicle/20 -> https://swapi.co/vocabulary/vehicleClass -> repulsorcraft
# https://swapi.co/resource/planet/45 -> https://swapi.co/vocabulary/rotationPeriod -> 29
# https://swapi.co/resource/human/39 -> https://swapi.co/vocabulary/skinColor -> fair
# https://swapi.co/resource/planet/1 -> https://swapi.co/vocabulary/gravity -> 1 standard
# https://swapi.co/resource/vehicle/55 -> https://swapi.co/vocabulary/model -> Flitknot speeder
# https://swapi.co/resource/vehicle/70 -> https://swapi.co/vocabulary/vehicleClass -> air speeder
# https://swapi.co/resource/human/42 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/planet/17 -> http://www.w3.org/2000/01/rdf-schema#label -> Felucia
# https://swapi.co/vocabulary/Skakoan -> https://swapi.co/vocabulary/language -> Skakoan
# https://swapi.co/resource/starship/52 -> https://swapi.co/vocabulary/starshipClass -> assault ship
# https://swapi.co/resource/film/2 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/20
# https://swapi.co/resource/gungan/37 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/8
# https://swapi.co/resource/planet/34 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/toydarian/40
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/vulptereen/48
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/21
# https://swapi.co/vocabulary/Droid -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/1
# https://swapi.co/resource/film/7 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/droid/3
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/neimodian/33
# https://swapi.co/resource/human/67 -> https://swapi.co/vocabulary/birthYear -> 102BBY
# https://swapi.co/resource/human/35 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/64
# https://swapi.co/resource/vehicle/20 -> https://swapi.co/vocabulary/costInCredits -> 75000
# https://swapi.co/resource/kaleesh/79 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/59
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/skinColor -> black
# https://swapi.co/resource/keldor/58 -> https://swapi.co/vocabulary/mass -> 80.0
# https://swapi.co/vocabulary/Neimodian -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/starship/5 -> https://swapi.co/vocabulary/consumables -> 1 month
# https://swapi.co/vocabulary/Besalisk -> https://swapi.co/vocabulary/eyeColor -> yellow
# https://swapi.co/vocabulary/Kaminoan -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/kaminoan/72
# https://swapi.co/resource/vehicle/19 -> https://swapi.co/vocabulary/manufacturer -> Kuat Drive Yards, Imperial Department of Military Research
# https://swapi.co/resource/planet/50 -> https://swapi.co/vocabulary/orbitalPeriod -> 318
# https://swapi.co/resource/human/60 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/vehicle/70 -> https://swapi.co/vocabulary/passengers -> 0
# https://swapi.co/resource/quermian/57 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Quermian
# https://swapi.co/vocabulary/Kaminoan -> https://swapi.co/vocabulary/averageLifespan -> 80
# https://swapi.co/resource/toydarian/40 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/34
# https://swapi.co/resource/planet/12 -> https://swapi.co/vocabulary/terrain -> scrublands, savanna, canyons, sinkholes
# https://swapi.co/resource/vehicle/19 -> https://swapi.co/vocabulary/passengers -> 0
# https://swapi.co/resource/starship/58 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 1600
# https://swapi.co/resource/starship/23 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/2
# https://swapi.co/resource/starship/15 -> https://swapi.co/vocabulary/costInCredits -> 1143350000
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/67
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/43
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/39
# https://swapi.co/resource/starship/27 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/vocabulary/Ewok -> https://swapi.co/vocabulary/eyeColor -> brown
# https://swapi.co/resource/vehicle/55 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 634
# https://swapi.co/resource/vehicle/57 -> https://swapi.co/vocabulary/vehicleClass -> starfighter
# https://swapi.co/resource/vehicle/33 -> https://swapi.co/vocabulary/cargoCapacity -> 0
# https://swapi.co/resource/human/4 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/human/25 -> https://swapi.co/vocabulary/desc -> Lando Calrissian is a fictional character in the Star Wars franchise. He is portrayed by Billy Dee Williams in The Empire Strikes Back and Return of the Jedi, and will be played by Donald Glover in the upcoming standalone film, Solo: A Star Wars Story.1 He also appears frequently in the Star Wars expanded universe of novels, comic books and video games, including a series of novels in which he is the protagonist.
# https://swapi.co/resource/planet/16 -> https://swapi.co/vocabulary/orbitalPeriod -> 167
# https://swapi.co/resource/planet/32 -> https://swapi.co/vocabulary/rotationPeriod -> 20
# https://swapi.co/resource/starship/15 -> https://swapi.co/vocabulary/altDesc -> An executor is someone who is responsible for executing, or following through on, an assigned task or duty. The feminine form, executrix, may sometimes be used. The role of an executor should not be confused with that of an executioner, a person who carries out a death sentence ordered by the state or other legal authority.
# https://swapi.co/resource/starship/40 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/starship/49 -> https://swapi.co/vocabulary/manufacturer -> Theed Palace Space Vessel Engineering Corps
# https://swapi.co/resource/starship/28 -> https://swapi.co/vocabulary/altDesc -> A-wings are fictional starfighters in the Star Wars franchise. They first appear in Return of the Jedi (1983) and later in numerous Star Wars materials and productions. It gained popularity through its depiction in several video games, and since 1985 the A-wing has been merchandised by several companies.
# https://swapi.co/resource/starship/27 -> https://swapi.co/vocabulary/model -> MC80 Liberty type Star Cruiser
# https://swapi.co/resource/gungan/36 -> https://swapi.co/vocabulary/hairColor -> none
# https://swapi.co/resource/planet/34 -> https://swapi.co/vocabulary/terrain -> swamps, lakes
# https://swapi.co/resource/human/61 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/8
# https://swapi.co/resource/planet/10 -> https://swapi.co/vocabulary/rotationPeriod -> 27
# https://swapi.co/resource/film/7 -> http://www.w3.org/2000/01/rdf-schema#label -> The Force Awakens
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/zabrak/54
# https://swapi.co/resource/starship/48 -> https://swapi.co/vocabulary/model -> Delta-7 Aethersprite-class interceptor
# https://swapi.co/resource/human/11 -> https://swapi.co/vocabulary/skinColor -> fair
# https://swapi.co/resource/starship/27 -> https://swapi.co/vocabulary/passengers -> 1200
# https://swapi.co/resource/starship/2 -> https://swapi.co/vocabulary/crew -> 165
# https://swapi.co/resource/starship/65 -> https://swapi.co/vocabulary/starshipClass -> starfighter
# https://swapi.co/resource/yodasspecies/20 -> https://swapi.co/vocabulary/skinColor -> green
# https://swapi.co/resource/starship/29 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/twilek/46 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/starship/61 -> https://swapi.co/vocabulary/hyperdriveRating -> 1.0
# https://swapi.co/resource/mirialan/65 -> https://swapi.co/vocabulary/mass -> 50.0
# https://swapi.co/resource/kaleesh/79 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/starship/52 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/human/68 -> http://www.w3.org/2000/01/rdf-schema#label -> Bail Prestor Organa
# https://swapi.co/resource/droid/2 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/2
# https://swapi.co/vocabulary/Dug -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/66
# https://swapi.co/vocabulary/Yodasspecies -> https://swapi.co/vocabulary/eyeColor -> green
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/openingCrawl -> Turmoil has engulfed the
# Galactic Republic. The taxation
# of trade routes to outlying star
# systems is in dispute.
#
# Hoping to resolve the matter
# with a blockade of deadly
# battleships, the greedy Trade
# Federation has stopped all
# shipping to the small planet
# of Naboo.
#
# While the Congress of the
# Republic endlessly debates
# this alarming chain of events,
# the Supreme Chancellor has
# secretly dispatched two Jedi
# Knights, the guardians of
# peace and justice in the
# galaxy, to settle the conflict....
# https://swapi.co/vocabulary/Clawdite -> https://swapi.co/vocabulary/averageLifespan -> 70
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/7
# https://swapi.co/resource/vehicle/6 -> https://swapi.co/vocabulary/crew -> 1
# https://swapi.co/resource/planet/52 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/planet -> https://swapi.co/resource/planet/15
# https://swapi.co/resource/human/28 -> https://swapi.co/vocabulary/eyeColor -> blue
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/53
# https://swapi.co/resource/starship/43 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/starship/12 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 1050
# https://swapi.co/vocabulary/Geonosian -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/vocabulary/Geonosian -> https://swapi.co/vocabulary/eyeColor -> hazel
# https://swapi.co/resource/planet/39 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/vehicle/60 -> https://swapi.co/vocabulary/costInCredits -> 15000
# https://swapi.co/resource/vehicle/60 -> https://swapi.co/vocabulary/manufacturer -> Z-Gomot Ternbuell Guppat Corporation
# https://swapi.co/resource/human/86 -> https://swapi.co/vocabulary/eyeColor -> brown
# https://swapi.co/resource/starship/12 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/resource/hutt/16 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/vocabulary/Vulptereen -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/vulptereen/48
# https://swapi.co/resource/vehicle/4 -> https://swapi.co/vocabulary/length -> 36.8
# https://swapi.co/vocabulary/Tholothian -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Species
# https://swapi.co/resource/planet/5 -> https://swapi.co/vocabulary/diameter -> 8900
# https://swapi.co/vocabulary/Mirialan -> http://www.w3.org/2000/01/rdf-schema#subClassOf -> https://swapi.co/vocabulary/Mammal
# https://swapi.co/resource/human/10 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/48
# https://swapi.co/resource/starship/23 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/starship/75 -> http://www.w3.org/2000/01/rdf-schema#label -> V-wing
# https://swapi.co/resource/starship/12 -> http://www.w3.org/2000/01/rdf-schema#label -> X-wing
# https://swapi.co/resource/planet/8 -> https://swapi.co/vocabulary/surfaceWater -> 12
# https://swapi.co/vocabulary/Tholothian -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/tholothian/55
# https://swapi.co/resource/film/1 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/10
# https://swapi.co/resource/droid/75 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Droid
# https://swapi.co/resource/zabrak/54 -> http://www.w3.org/2000/01/rdf-schema#label -> Eeth Koth
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/54
# https://swapi.co/resource/starship/3 -> https://swapi.co/vocabulary/altDesc -> Star Destroyers are capital ships in the fictional Star Wars universe. The Imperial Star Destroyer, which first appears in the first seconds of Star Wars (1977), is "the signature vessel of the Imperial fleet".2 The term "Star Destroyer" also refers to other vessels in the franchise., Numerous Star Destroyer models and toys have been released, and the iconic scene featuring the vessel\s first appearance has been called "a milestone in special effects history".
# https://swapi.co/resource/human/5 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/1
# https://swapi.co/resource/planet/27 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/vehicle/67 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Vehicle
# https://swapi.co/resource/zabrak/54 -> https://swapi.co/vocabulary/eyeColor -> brown
# https://swapi.co/resource/dug/41 -> https://swapi.co/vocabulary/hairColor -> none
# https://swapi.co/resource/ewok/30 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/vehicle/30 -> https://swapi.co/vocabulary/crew -> 1
# https://swapi.co/resource/planet/61 -> https://swapi.co/vocabulary/altDesc -> Jakku ist ein fiktiver Wüstenplanet, der erstmals im Star Wars-Film The Force Awakens 2015 vorgestellt wurde. Fern, gesetzlos und unwirtlich ist es die Heimatwelt der Hauptfigur Rey, gespielt von Daisy Ridley. Der Film konzentriert sich auf zwei verschiedene Orte, Tuanul Village und Niima Outpost, in der Nähe eines Raumschiff-Friedhofs. "Der Planet ist auch im Chuck Wendig-Roman von 2017, Star Wars: Aftermath: Empires End, dargestellt."
# https://swapi.co/resource/zabrak/44 -> https://swapi.co/vocabulary/birthYear -> 54BBY
# https://swapi.co/resource/vehicle/34 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/mirialan/65 -> https://swapi.co/vocabulary/skinColor -> yellow
# https://swapi.co/resource/trandoshan/24 -> http://www.w3.org/2000/01/rdf-schema#label -> Bossk
# https://swapi.co/resource/starship/29 -> https://swapi.co/vocabulary/length -> 16.9
# https://swapi.co/vocabulary/Ewok -> https://swapi.co/vocabulary/eyeColor -> orange
# https://swapi.co/resource/planet/26 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/human/19
# https://swapi.co/resource/starship/47 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/vocabulary/Pauan -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/starship/41 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/xexto/49 -> https://swapi.co/vocabulary/height -> 122.0
# https://swapi.co/resource/vehicle/51 -> http://www.w3.org/2000/01/rdf-schema#label -> LAAT/c
# https://swapi.co/vocabulary/Hutt -> http://www.w3.org/2000/01/rdf-schema#subClassOf -> https://swapi.co/vocabulary/Gastropod
# https://swapi.co/vocabulary/Togruta -> https://swapi.co/vocabulary/language -> Togruti
# https://swapi.co/resource/mirialan/64 -> https://swapi.co/vocabulary/eyeColor -> blue
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/releaseDate -> 2002-05-16
# https://swapi.co/resource/human/10 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/64
# https://swapi.co/resource/human/66 -> https://swapi.co/vocabulary/hairColor -> brown
# https://swapi.co/vocabulary/Besalisk -> https://swapi.co/vocabulary/averageHeight -> 178.0
# https://swapi.co/resource/starship/75 -> https://swapi.co/vocabulary/altDesc -> Il y a eu plusieurs véhicules dans l'univers Star Wars désignés V-wing
# https://swapi.co/resource/vehicle/18 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 60
# https://swapi.co/vocabulary/Clawdite -> http://www.w3.org/2000/01/rdf-schema#subClassOf -> https://swapi.co/vocabulary/Sentient
# https://swapi.co/resource/aleena/47 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/gungan/38 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/vehicle/46 -> https://swapi.co/vocabulary/pilot -> https://swapi.co/resource/human/11
# https://swapi.co/vocabulary/Wookiee -> https://swapi.co/vocabulary/skinColor -> gray
# https://swapi.co/resource/human/9 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/1
# https://swapi.co/resource/starship/10 -> https://swapi.co/vocabulary/length -> 34.37
# https://swapi.co/vocabulary/Mirialan -> https://swapi.co/vocabulary/eyeColor -> yellow
# https://swapi.co/resource/starship/28 -> https://swapi.co/vocabulary/mglt -> 120
# https://swapi.co/resource/human/32 -> https://swapi.co/vocabulary/height -> 193.0
# https://swapi.co/resource/tholothian/55 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/vehicle/53 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/human/10 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/2
# https://swapi.co/resource/film/3 -> https://swapi.co/vocabulary/desc -> Return of the Jedi (also known as Star Wars: Episode VI – Return of the Jedi) is a 1983 American epic space opera film directed by Richard Marquand. The screenplay by Lawrence Kasdan and George Lucas was from a story by Lucas, who was also the executive producer. It is the third installment in the original Star Wars trilogy and the first film to use THX technology. The film is set one year after The Empire Strikes Back9 and was produced by Howard Kazanjian for Lucasfilm Ltd. The film stars Mark Hamill, Harrison Ford, Carrie Fisher, Billy Dee Williams, Anthony Daniels, David Prowse, Kenny Baker, Peter Mayhew and Frank Oz., "The Galactic Empire, under the direction of the ruthless Emperor, is constructing a second Death Star in order to crush the Rebel Alliance once and for all. Since the Emperor plans to personally oversee the final stages of its construction, the Rebel Fleet launches a full-scale attack on the Death Star in order to prevent its completion and kill the Emperor, effectively bringing an end to the Empires hold over the galaxy. Meanwhile, Luke Skywalker, a Jedi apprentice, struggles to bring his father Darth Vader back to the Light Side of the Force.", "David Lynch and David Cronenberg were considered to direct the project before Marquand signed on as director. The production team relied on Lucas storyboards during pre-production. While writing the shooting script, Lucas, Kasdan, Marquand, and producer Howard Kazanjian spent two weeks in conference discussing ideas to construct it. Kazanjians schedule pushed shooting to begin a few weeks early to allow Industrial Light & Magic more time to work on the films effects in post-production. Filming took place in England, California, and Arizona from January to May\xa01982\xa0(1982-05). Strict secrecy surrounded the production and the film used the working title Blue Harvest to prevent price gouging.", "The film was released in theaters on May 25, 1983, six years to the day after the release of the first film, receiving mostly positive reviews. The film grossed between $475 million67 and $572 million worldwide.8 Several home video and theatrical releases and revisions to the film followed over the next 20 years. Star Wars continued with The Phantom Menace as part of the film series prequel trilogy.", A sequel, The Force Awakens, was released on December 18, 2015, as part of the new sequel trilogy.10
# https://swapi.co/resource/vehicle/54 -> https://swapi.co/vocabulary/cargoCapacity -> 500
# https://swapi.co/resource/vehicle/53 -> https://swapi.co/vocabulary/passengers -> 36
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/twilek/46
# https://swapi.co/resource/planet/6 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/planet/35 -> http://www.w3.org/2000/01/rdf-schema#label -> Malastare
# https://swapi.co/resource/planet/23 -> https://swapi.co/vocabulary/rotationPeriod -> 29
# https://swapi.co/vocabulary/Kaleesh -> https://swapi.co/vocabulary/skinColor -> brown
# https://swapi.co/resource/vehicle/51 -> https://swapi.co/vocabulary/crew -> 1
# https://swapi.co/resource/cerean/52 -> https://swapi.co/vocabulary/eyeColor -> yellow
# https://swapi.co/resource/starship/13 -> https://swapi.co/vocabulary/pilot -> https://swapi.co/resource/human/4
# https://swapi.co/resource/vehicle/45 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/starship/29 -> https://swapi.co/vocabulary/passengers -> 0
# https://swapi.co/resource/planet/34 -> https://swapi.co/vocabulary/climate -> temperate
# https://swapi.co/resource/film/1 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Film
# https://swapi.co/resource/starship/23 -> https://swapi.co/vocabulary/cargoCapacity -> 6000000
# https://swapi.co/resource/vehicle/72 -> https://swapi.co/vocabulary/vehicleClass -> droid tank
# https://swapi.co/resource/hutt/16 -> https://swapi.co/vocabulary/gender -> hermaphrodite
# https://swapi.co/vocabulary/Iktotchi -> https://swapi.co/vocabulary/language -> Iktotchese
# https://swapi.co/resource/vehicle/53 -> http://www.w3.org/2000/01/rdf-schema#label -> AT-TE
# https://swapi.co/resource/vehicle/8 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Vehicle
# https://swapi.co/resource/planet/10 -> https://swapi.co/vocabulary/gravity -> 1 standard
# https://swapi.co/vocabulary/Yodasspecies -> http://www.w3.org/2000/01/rdf-schema#label -> Yodasspecies
# https://swapi.co/resource/human/74 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/74
# https://swapi.co/resource/zabrak/44 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/vehicle/14 -> https://swapi.co/vocabulary/passengers -> 0
# https://swapi.co/resource/starship/65 -> https://swapi.co/vocabulary/crew -> 1
# https://swapi.co/resource/wookiee/13 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/6
# https://swapi.co/resource/vehicle/76 -> https://swapi.co/vocabulary/length -> 3.2
# https://swapi.co/vocabulary/Besalisk -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/besalisk/71
# https://swapi.co/resource/planet/43 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/human/68 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Human
# https://swapi.co/resource/human/51 -> https://swapi.co/vocabulary/mass -> 84.0
# https://swapi.co/resource/starship/22 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/resource/planet/25 -> https://swapi.co/vocabulary/terrain -> oceans, savannas, mountains, grasslands
# https://swapi.co/resource/vehicle/50 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/starship/61 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/starship/3 -> https://swapi.co/vocabulary/manufacturer -> Kuat Drive Yards
# https://swapi.co/resource/toong/50 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/planet/54 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/vocabulary/Muun -> http://www.w3.org/2000/01/rdf-schema#label -> Muun
# https://swapi.co/resource/mirialan/64 -> https://swapi.co/vocabulary/height -> 170.0
# https://swapi.co/resource/film/3 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/15
# https://swapi.co/resource/human/21 -> https://swapi.co/vocabulary/birthYear -> 82BBY
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/hairColor -> blonde
# https://swapi.co/resource/planet/41 -> https://swapi.co/vocabulary/orbitalPeriod -> 1770
# https://swapi.co/resource/starship/23 -> https://swapi.co/vocabulary/starshipClass -> Escort ship
# https://swapi.co/resource/aleena/47 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/38
# https://swapi.co/resource/starship/77 -> http://www.w3.org/2000/01/rdf-schema#label -> T-70 X-wing fighter
# https://swapi.co/resource/planet/3 -> https://swapi.co/vocabulary/surfaceWater -> 8
# https://swapi.co/resource/vehicle/72 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Vehicle
# https://swapi.co/resource/human/21 -> https://swapi.co/vocabulary/skinColor -> pale
# https://swapi.co/resource/vehicle/46 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/quermian/57 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/planet/5 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/vocabulary/Toydarian -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/planet/14 -> https://swapi.co/vocabulary/rotationPeriod -> 26
# https://swapi.co/resource/planet/45 -> http://www.w3.org/2000/01/rdf-schema#label -> Iridonia
# https://swapi.co/resource/vehicle/24 -> https://swapi.co/vocabulary/model -> Modified Luxury Sail Barge
# https://swapi.co/resource/yodasspecies/20 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/planet/23 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/human/51 -> https://swapi.co/vocabulary/height -> 188.0
# https://swapi.co/resource/planet/27 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/vocabulary/Zabrak -> https://swapi.co/vocabulary/hairColor -> black
# https://swapi.co/resource/besalisk/71 -> https://swapi.co/vocabulary/mass -> 102.0
# https://swapi.co/vocabulary/Xexto -> https://swapi.co/vocabulary/eyeColor -> black
# https://swapi.co/resource/film/7 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/14
# https://swapi.co/resource/starship/59 -> https://swapi.co/vocabulary/crew -> 600
# https://swapi.co/resource/vehicle/19 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/2
# https://swapi.co/vocabulary/Togruta -> https://swapi.co/vocabulary/skinColor -> white
# https://swapi.co/resource/planet/14 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/wookiee/13
# https://swapi.co/resource/vehicle/56 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 880
# https://swapi.co/resource/starship/32 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/starship/23 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 800
# https://swapi.co/resource/keldor/58 -> https://swapi.co/vocabulary/birthYear -> 22BBY
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/43
# https://swapi.co/resource/starship/63 -> https://swapi.co/vocabulary/crew -> 7400
# ...
# https://swapi.co/resource/ewok/30 -> https://swapi.co/vocabulary/hairColor -> brown
# https://swapi.co/resource/starship/21 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/human/66 -> https://swapi.co/vocabulary/skinColor -> light
# https://swapi.co/vocabulary/Moncalamari -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/vocabulary/Muun -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Species
# https://swapi.co/vocabulary/Mirialan -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/planet/22 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/vehicle/14 -> https://swapi.co/vocabulary/consumables -> none
# https://swapi.co/resource/planet/17 -> https://swapi.co/vocabulary/population -> 8500000
# https://swapi.co/resource/starship/29 -> https://swapi.co/vocabulary/manufacturer -> Slayn & Korpil
# https://swapi.co/resource/vehicle/51 -> https://swapi.co/vocabulary/manufacturer -> Rothana Heavy Engineering
# https://swapi.co/vocabulary/Togruta -> https://swapi.co/vocabulary/averageHeight -> 180.0
# https://swapi.co/vocabulary/Sullustan -> https://swapi.co/vocabulary/skinColor -> pale
# https://swapi.co/vocabulary/Mirialan -> https://swapi.co/vocabulary/hairColor -> brown
# https://swapi.co/resource/planet/5 -> http://www.w3.org/2000/01/rdf-schema#label -> Dagobah
# https://swapi.co/vocabulary/Keldor -> https://swapi.co/vocabulary/skinColor -> orange
# https://swapi.co/resource/vehicle/76 -> https://swapi.co/vocabulary/crew -> 1
# https://swapi.co/resource/neimodian/33 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/vocabulary/Aleena -> https://swapi.co/vocabulary/skinColor -> gray
# https://swapi.co/resource/yodasspecies/20 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/resource/starship/31 -> https://swapi.co/vocabulary/hyperdriveRating -> 2.0
# https://swapi.co/vocabulary/Reptile -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> http://www.w3.org/2000/01/rdf-schema#Class
# https://swapi.co/resource/human/68 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/vehicle/30 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Vehicle
# https://swapi.co/resource/planet/59 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/planet/49 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/keldor/58
# https://swapi.co/resource/vehicle/42 -> https://swapi.co/vocabulary/cargoCapacity -> 2
# https://swapi.co/resource/vehicle/53 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 60
# https://swapi.co/resource/human/84 -> https://swapi.co/vocabulary/desc -> Finn, designation number FN-2187, is a fictional character in the Star Wars franchise. He first appeared in the 2015 film Star Wars: The Force Awakens in which he is a stormtrooper for the First Order who flees and turns against it after being shocked by their cruelty in his first combat mission. He is played by British actor John Boyega, who will reprise the role in Star Wars: The Last Jedi.
# https://swapi.co/resource/vehicle/8 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/planet/30 -> https://swapi.co/vocabulary/rotationPeriod -> 20
# https://swapi.co/resource/human/22 -> https://swapi.co/vocabulary/height -> 183.0
# https://swapi.co/resource/planet/30 -> https://swapi.co/vocabulary/terrain -> deserts, mountains
# https://swapi.co/vocabulary/Pauan -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/human/51 -> https://swapi.co/vocabulary/birthYear -> 72BBY
# https://swapi.co/vocabulary/Droid -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/film/1 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/9
# https://swapi.co/resource/human/51 -> https://swapi.co/vocabulary/hairColor -> none
# https://swapi.co/resource/vehicle/36 -> http://www.w3.org/2000/01/rdf-schema#label -> Single Trooper Aerial Platform
# https://swapi.co/resource/starship/31 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/vehicle/46 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Vehicle
# https://swapi.co/resource/starship/29 -> http://www.w3.org/2000/01/rdf-schema#label -> B-wing
# https://swapi.co/vocabulary/Toong -> https://swapi.co/vocabulary/eyeColor -> orange
# https://swapi.co/vocabulary/Yodasspecies -> https://swapi.co/vocabulary/eyeColor -> brown
# https://swapi.co/vocabulary/Ewok -> https://swapi.co/vocabulary/hairColor -> black
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/toydarian/40
# https://swapi.co/resource/starship/74 -> http://www.w3.org/2000/01/rdf-schema#label -> Belbullab-22 starfighter
# https://swapi.co/resource/vehicle/53 -> https://swapi.co/vocabulary/altDesc -> Les marcheurs sont des véhicules de l'univers Star Wars qui parcourent le paysage sur des jambes mécaniques. Ils sont utilisés par l'Ancienne République et l'Empire Galactique pour les assauts au sol ou le transport. Tout au long de la saga, les marcheurs ont joué un rôle central dans le sort des personnages et l'issue des batailles. Industrial Light and Magic (ILM) est responsable de leur animation et de leur conception, souvent en utilisant des modèles, des animations en stop-motion et des peintures mates pertinentes pour représenter leur présence dans les films., Il existe une variété de marcheurs: l'Empire Strikes Back présente le Transport Blindé Tout Terrain (AT-AT) et Transport Scout All Terrain (AT-ST). Star Wars: Episode II - L'attaque des clones et Star Wars: Episode III - La vengeance des Sith ont présenté des modèles de marcheurs antérieurs, tels que l'AT-TE, et l'univers élargi de Star Wars en comporte de nombreux autres. Les variantes Walker ont été commercialisées et présentées dans la culture populaire.
# https://swapi.co/resource/human/60 -> https://swapi.co/vocabulary/height -> 185.0
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/11
# https://swapi.co/resource/starship/9 -> https://swapi.co/vocabulary/cargoCapacity -> 1000000000000
# https://swapi.co/resource/planet/49 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/human/35 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/planet/8 -> https://swapi.co/vocabulary/terrain -> grassy hills, swamps, forests, mountains
# https://swapi.co/resource/film/3 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/moncalamari/27
# https://swapi.co/resource/human/85 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/7
# https://swapi.co/resource/starship/75 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/mirialan/64 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/51
# https://swapi.co/resource/starship/43 -> http://www.w3.org/2000/01/rdf-schema#label -> J-type diplomatic barge
# https://swapi.co/vocabulary/Togruta -> https://swapi.co/vocabulary/eyeColor -> red
# https://swapi.co/vocabulary/Yodasspecies -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/yodasspecies/20
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/aleena/47
# https://swapi.co/resource/xexto/49 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/4
# https://swapi.co/resource/vehicle/62 -> https://swapi.co/vocabulary/crew -> 2
# https://swapi.co/resource/vehicle/70 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 310
# https://swapi.co/resource/mirialan/65 -> https://swapi.co/vocabulary/height -> 166.0
# https://swapi.co/resource/starship/27 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/twilek/45 -> https://swapi.co/vocabulary/hairColor -> none
# https://swapi.co/resource/planet/59 -> https://swapi.co/vocabulary/terrain -> rainforests, cliffs, canyons, seas
# https://swapi.co/vocabulary/Hutt -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/3
# https://swapi.co/resource/nautolan/53 -> https://swapi.co/vocabulary/hairColor -> none
# https://swapi.co/vocabulary/Kaminoan -> https://swapi.co/vocabulary/skinColor -> grey
# https://swapi.co/resource/human/67 -> https://swapi.co/vocabulary/skinColor -> fair
# https://swapi.co/resource/planet/42 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/human/84 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/toong/50 -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/vehicle/45 -> https://swapi.co/vocabulary/manufacturer -> Desler Gizh Outworld Mobility Corporation
# https://swapi.co/vocabulary/Wookiee -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/6
# https://swapi.co/resource/droid/2 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/4
# https://swapi.co/resource/vehicle/67 -> https://swapi.co/vocabulary/passengers -> 0
# https://swapi.co/vocabulary/Zabrak -> https://swapi.co/vocabulary/skinColor -> brown
# https://swapi.co/resource/human/9 -> https://swapi.co/vocabulary/hairColor -> black
# https://swapi.co/resource/human/22 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/2
# https://swapi.co/resource/planet/25 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Planet
# https://swapi.co/resource/starship/11 -> https://swapi.co/vocabulary/manufacturer -> Koensayr Manufacturing
# https://swapi.co/resource/vehicle/7 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/1
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/7
# https://swapi.co/vocabulary/Aleena -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Species
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/57
# https://swapi.co/vocabulary/Clawdite -> https://swapi.co/vocabulary/skinColor -> green
# https://swapi.co/resource/film/1 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/12
# https://swapi.co/resource/film/2 -> https://swapi.co/vocabulary/planet -> https://swapi.co/resource/planet/5
# https://swapi.co/resource/droid/75 -> https://swapi.co/vocabulary/homeworld -> https://swapi.co/resource/planet/28
# https://swapi.co/resource/starship/75 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/32
# https://swapi.co/resource/vehicle/16 -> https://swapi.co/vocabulary/altDesc -> TIE fighters are fictional starfighters in the Star Wars universe. Propelled by twin ion engines (hence the TIE acronym), TIE fighters are fast, agile, yet fragile starfighters produced by Sienar Fleet Systems for the Galactic Empire. TIE fighters and other TIE craft appear in Star Wars films, television shows, and throughout the Star Wars expanded universe. Several TIE fighter replicas and toys, as well as a TIE flight simulator, have been produced and sold by merchandise companies.
# https://swapi.co/resource/film/4 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/droid/3
# https://swapi.co/resource/tholothian/55 -> https://swapi.co/vocabulary/eyeColor -> blue
# https://swapi.co/vocabulary/Toong -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/toong/50
# https://swapi.co/resource/vehicle/60 -> https://swapi.co/vocabulary/maxAtmospheringSpeed -> 330
# https://swapi.co/resource/starship/65 -> https://swapi.co/vocabulary/passengers -> 0
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/53
# https://swapi.co/vocabulary/Cerean -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Species
# https://swapi.co/resource/film/3 -> https://swapi.co/vocabulary/vehicle -> https://swapi.co/resource/vehicle/25
# https://swapi.co/resource/vehicle/71 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Vehicle
# https://swapi.co/resource/planet/48 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/quermian/57
# https://swapi.co/resource/sullustan/31 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/starship/12 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/1
# https://swapi.co/resource/starship/5 -> https://swapi.co/vocabulary/hyperdriveRating -> 1.0
# https://swapi.co/resource/vehicle/73 -> https://swapi.co/vocabulary/model -> HMP droid gunship
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/planet -> https://swapi.co/resource/planet/18
# https://swapi.co/vocabulary/Human -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/human/14
# https://swapi.co/resource/vehicle/38 -> https://swapi.co/vocabulary/manufacturer -> Otoh Gunga Bongameken Cooperative
# https://swapi.co/vocabulary/Geonosian -> http://www.w3.org/2000/01/rdf-schema#label -> Geonosian
# https://swapi.co/vocabulary/Vulptereen -> https://swapi.co/vocabulary/language -> vulpterish
# https://swapi.co/resource/planet/56 -> https://swapi.co/vocabulary/terrain -> urban, vines
# https://swapi.co/resource/planet/6 -> https://swapi.co/vocabulary/climate -> temperate
# https://swapi.co/resource/planet/1 -> https://swapi.co/vocabulary/resident -> https://swapi.co/resource/droid/8
# https://swapi.co/resource/starship/12 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Starship
# https://swapi.co/resource/starship/77 -> https://swapi.co/vocabulary/model -> T-70 X-wing fighter
# https://swapi.co/resource/vehicle/24 -> https://swapi.co/vocabulary/length -> 30.0
# https://swapi.co/resource/vehicle/70 -> https://swapi.co/vocabulary/manufacturer -> Appazanna Engineering Works
# https://swapi.co/resource/human/12 -> https://swapi.co/vocabulary/birthYear -> 64BBY
# https://swapi.co/resource/human/18 -> https://swapi.co/vocabulary/starship -> https://swapi.co/resource/starship/12
# https://swapi.co/resource/film/6 -> https://swapi.co/vocabulary/character -> https://swapi.co/resource/tholothian/55
# https://swapi.co/vocabulary/Aleena -> https://swapi.co/vocabulary/language -> Aleena
# https://swapi.co/vocabulary/Cerean -> https://swapi.co/vocabulary/averageHeight -> 200.0
# https://swapi.co/vocabulary/Quermian -> https://swapi.co/vocabulary/skinColor -> white
# https://swapi.co/vocabulary/Rodian -> https://swapi.co/vocabulary/desc -> None
# https://swapi.co/resource/planet/57 -> https://swapi.co/vocabulary/orbitalPeriod -> 412
# https://swapi.co/resource/human/7 -> https://swapi.co/vocabulary/hairColor -> brown
# https://swapi.co/resource/human/35 -> https://swapi.co/vocabulary/film -> https://swapi.co/resource/film/5
# https://swapi.co/resource/film/5 -> https://swapi.co/vocabulary/planet -> https://swapi.co/resource/planet/10
# https://swapi.co/resource/planet/36 -> https://swapi.co/vocabulary/rotationPeriod -> 24
# https://swapi.co/resource/vehicle/37 -> https://swapi.co/vocabulary/passengers -> 284
# https://swapi.co/resource/human/26 -> https://swapi.co/vocabulary/gender -> male
# https://swapi.co/resource/human/4 -> http://www.w3.org/1999/02/22-rdf-syntax-ns#type -> https://swapi.co/vocabulary/Character
# https://swapi.co/resource/planet/1 -> https://swapi.co/vocabulary/surfaceWater -> 1

# %% [markdown]
# # Parse articles from Wikipedia and construct KG

# %% [markdown]
# https://stackabuse.com/getting-started-with-pythons-wikipedia-api/

# %%
import wikipedia

# %%
wikipedia.search('Millennium Falcon')
# Out:
# ['Millennium Falcon',
#  'Star Wars: Millennium Falcon – Smugglers Run',
#  'Millennium Falcon (novel)',
#  'Chewbacca',
#  'Falcon 9',
#  'Berserk: Millennium Falcon Hen Seima Senki no Shō',
#  'Lando Calrissian',
#  'Solo: A Star Wars Story',
#  'Han Solo',
#  "Star Wars: Galaxy's Edge"]

# %%
wikipedia.summary('Millennium Falcon')
# Out:
# "The Millennium Falcon is a fictional starship in the Star Wars franchise. Designed by Joe Johnston for the movie Star Wars (1977), it has subsequently appeared in The Star Wars Holiday Special (1978), The Empire Strikes Back (1980), Return of the Jedi (1983), The Force Awakens (2015), The Last Jedi (2017), Solo: A Star Wars Story (2018), and The Rise of Skywalker (2019). The starship, or a similar one, also has a cameo in Revenge of the Sith (2005). Additionally, the Falcon appears in a variety of Star Wars expanded universe materials, including books, comics, and games; James Luceno's novel Millennium Falcon focuses on the titular ship. It also appears in the 2014 animated film The Lego Movie in Lego form, with Billy Dee Williams and Anthony Daniels reprising their roles of Lando Calrissian and C-3PO, and Keith Ferguson voicing Han Solo.\nSolo: A Star Wars Story depicts the YT-1300 Corellian light freighter being embodied by L3-37 (Phoebe Waller-Bridge). The ship is primarily commanded by smuggler Han Solo (Harrison Ford and Alden Ehrenreich) and his Wookiee first mate, Chewbacca (Peter Mayhew and Joonas Suotamo), and was previously owned by gambler con-artist Lando Calrissian (Billy Dee Williams and Donald Glover). Described as being one of the fastest vessels in the Star Wars canon, the Falcon looks like a worn-out junker, but despite its humble origins and shabby exterior, the Millennium Falcon has played a critical role in some of the greatest victories of the Rebel Alliance and the New Republic.\n\n"

# %%
wikipedia.page('Millennium Falcon').content
# Out:
# 'The Millennium Falcon is a fictional starship in the Star Wars franchise. Designed by Joe Johnston for the movie Star Wars (1977), it has subsequently appeared in The Star Wars Holiday Special (1978), The Empire Strikes Back (1980), Return of the Jedi (1983), The Force Awakens (2015), The Last Jedi (2017), Solo: A Star Wars Story (2018), and The Rise of Skywalker (2019). The starship, or a similar one, also has a cameo in Revenge of the Sith (2005). Additionally, the Falcon appears in a variety of Star Wars expanded universe materials, including books, comics, and games; James Luceno\'s novel Millennium Falcon focuses on the titular ship. It also appears in the 2014 animated film The Lego Movie in Lego form, with Billy Dee Williams and Anthony Daniels reprising their roles of Lando Calrissian and C-3PO, and Keith Ferguson voicing Han Solo.\nSolo: A Star Wars Story depicts the YT-1300 Corellian light freighter being embodied by L3-37 (Phoebe Waller-Bridge). The ship is primarily commanded by smuggler Han Solo (Harrison Ford and Alden Ehrenreich) and his Wookiee first mate, Chewbacca (Peter Mayhew and Joonas Suotamo), and was previously owned by gambler con-artist Lando Calrissian (Billy Dee Williams and Donald Glover). Described as being one of the fastest vessels in the Star Wars canon, the Falcon looks like a worn-out junker, but despite its humble origins and shabby exterior, the Millennium Falcon has played a critical role in some of the greatest victories of the Rebel Alliance and the New Republic.\n\n\n== Origin and design ==\nThe ship originally had a more elongated appearance, but this design\'s similarity to the Eagle Transporters in Space: 1999 prompted Lucas to change the Falcon\'s design. The original model was modified, re-scaled, and used as Princess Leia\'s ship, Tantive IV. Modelmaker Joe Johnston had about four weeks to redesign the Falcon, and Lucas\' only suggestion to Johnston was to "think of a flying saucer". Johnston did not want to produce a "basic flying saucer", so he created the offset cockpit, forward cargo mandibles, and rear slot for the engines. It was also said that the shape of the ship was roughly based on a hamburger with an olive-on-the-side cockpit. The design was simple enough to create in the four-week window. Johnston called production of the new Falcon design one of his most intense projects.The sound of the ship traveling through hyperspace comes from two tracks of the engine noise of a McDonnell Douglas DC-9, with one track slightly out of synchronization with the other to introduce a phasing effect. To this, sound designer Ben Burtt added the hum of the cooling fans on the motion-control rig at Industrial Light & Magic (ILM).\n\n\n=== Models and sets ===\n\nVisually, the Millennium Falcon was represented by several models and external and internal sets. For Star Wars, a partial exterior set was constructed and the set dressed as Mos Eisley\'s Docking Bay 94 and the Death Star hangar. Besides the functional landing gear, an additional support held up the structure and was disguised as a fuel line. The interior set included the starboard ring corridor, the boarding ramp, cockpit access tunnel, gun turret ladder, secret compartments, and the forward hold. The cockpit was constructed as a separate set that could be rocked when the ship was supposed to shake. Several inconsistencies exist between the internal set and the external set, the cockpit access tunnel angle being the most noticeable.\nThe effects models for Star Wars matched the design of the exterior set. The primary model was five feet long and detailed with various kit parts. The ship was represented by a matte painting when Princess Leia (Carrie Fisher) sees it for the first time, showing the full upper surface. For the 1997 "Special Edition", a digital model replaces the effects model in several shots, and is used in a new shot of the Falcon lifting off from Docking Bay 94.For The Empire Strikes Back, a new external set was  ...

# %%
mfalcon_article = wikipedia.page('Millennium Falcon').content

# %%
def text_to_graph(article, similarity_threshold):
    # Convert to triples
    triples = []
    with StanfordOpenIE() as client:
        for triple in client.annotate(article):
            triples.append(triple)
    print(f'Num of Triples: {len(triples)}')
    
    # Load BERT
    nlp = en_trf_bertbaseuncased_lg.load()
    article_enc = nlp(article)
    
    # Similarity Thresholding
    triples_filtered = []
    for triple in triples:
        statement = ' '.join(x for x in triple.values())
        similarity = article_enc.similarity(nlp(statement))
        if similarity > similarity_threshold:
            triples_filtered.append(triple)
    print(f'Filtered Triples: {len(triples_filtered)}')
    
    # Need to add step here for contexualization
    
    # Create RDF graph
    graph = Graph()
    for triple in triples_filtered:
        graph.add((
            rdflib.Literal(triple['subject'], datatype=rdflib.namespace.XSD.string),
            rdflib.Literal(triple['relation'], datatype=rdflib.namespace.XSD.string),
            rdflib.Literal(triple['object'], datatype=rdflib.namespace.XSD.string)
        ))
    
    return graph

# %%
graph = text_to_graph(article=mfalcon_article, similarity_threshold=0.75)
# Out:
# Starting server with command: java -Xmx8G -cp /Users/rhythmsyed/stanfordnlp_resources/stanford-corenlp-full-2018-10-05/* edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 60000 -threads 5 -maxCharLength 100000 -quiet True -serverProperties corenlp_server-712f785371b34522.props -preload openie
# Num of Triples: 1008
# Filtered Triples: 65

# %%
query_str = """
    SELECT ?s ?p ?o
    WHERE {   
        # ?s ?p ?o.
    }
"""
res = graph.query(query_str)

for s,p,o in res:
    print(s, '->', p, '->', o)
# Out:
# Star Wars Story -> depicts -> YT-1300 light freighter
# original model -> used as -> Princess Leia 's ship
# Chewbacca -> take possession after -> Solo 's hibernation
# Hot Wheels playset.Lego -> has released -> multiple versions of Millennium Falcon
# Calrissian captains -> is with -> Nien Nunb as co-pilot
# Hot Wheels playset.Lego -> has released -> versions of Millennium Falcon
# Lego -> released -> Millennium Falcon set in Star Wars Ultimate Collectors Series
# it -> has subsequently appeared in -> Return of Jedi
# Obi-Wan Kenobi -> charter ship In -> Star Wars
# Chewbacca -> Back take possession after -> Solo 's hibernation by Empire
# Creating Lando -> has -> Millennium Falcon for Solo Behind Magic of Kessel Run Millennium Falcon on Wookieepedia
# James Luceno 's Millennium Falcon -> focuses on -> ship
# Chewbacca -> Back take possession after -> Solo 's hibernation in carbonite by Empire
# Star Wars Story -> depicts -> YT-1300 freighter
# version -> appears -> briefly on Coruscant in Revenge of Sith
# updated Millennium Falcon -> set in -> Star Wars Ultimate Collectors Series
# several characters -> board Falcon in -> sandstorm on Tatooine
# Leia -> take possession after -> Solo 's hibernation by Empire
# Solo -> take planet to -> First Order 's new Starkiller Base
# Solo -> integrating -> memory module of Lando 's damaged L3 droid
# James Luceno 's novel Millennium Falcon -> focuses on -> titular ship
# Leia -> take possession after -> Solo 's hibernation in carbonite by Empire
# Creating Lando -> 's Falcon is -> Star Wars wiki Millennium Falcon Notes
# Solo -> take planet to -> First Order 's Starkiller Base
# Star Wars Story -> depicts -> YT-1300 Corellian freighter
# ship -> outrun Imperial TIE fighters during -> asteroid-field-escape scene from film
# Leia -> take possession after -> Solo 's hibernation
# Luke Skywalker -> charter ship In -> Star Wars
# Leia -> Back take possession after -> Solo 's hibernation by Empire
# Falcon 's distinct shape -> appear in -> Star Trek
# it -> has appeared in -> Star Wars Holiday
# model -> used as -> Princess Leia 's ship
# Chewbacca -> take possession after -> Solo 's hibernation in carbonite by Empire
# 32 model -> materials for -> Star Wars universe
# Leia -> Back take possession after -> Solo 's hibernation in carbonite by Empire
# Lando -> take possession after -> Solo 's hibernation by Empire
# Falcon 's shape -> appear in -> Star Trek
# Lego -> released -> updated Millennium Falcon set in Star Wars Ultimate Collectors Series
# it -> has subsequently appeared in -> Star Wars Holiday
# Lando -> take possession after -> Solo 's hibernation in carbonite by Empire
# Falcon -> appears again in -> Star Wars
# Chewbacca -> Back take possession after -> Solo 's hibernation in carbonite
# James Luceno 's novel Millennium Falcon -> focuses on -> ship
# Wheels -> has made -> model of ship for their Star Wars starship line
# model -> was -> version of Millennium Falcon most depicted in toys
# Luke Skywalker -> charter -> ship in Mos Eisley cantina
# Star Wars Story -> depicts -> YT-1300 Corellian light freighter
# digital version -> appears -> briefly on Coruscant in Revenge of Sith
# Solo -> take Finn to -> First Order 's new Starkiller Base
# Leia -> take possession after -> Solo 's hibernation in carbonite
# 32 model -> was -> version of Millennium Falcon most depicted in toys
# Solo -> take Finn to -> First Order 's Starkiller Base
# Princess Leia -> 's ship is -> Tantive IV
# Chewbacca -> take possession after -> Solo 's hibernation in carbonite
# Hot Wheels -> has made -> model of ship for their Star Wars starship line
# Leia -> Back take possession after -> Solo 's hibernation in carbonite
# Falcon -> appears in -> Star Wars
# Solo -> leaves Tatooine During -> Return of Jedi
# James Luceno 's Millennium Falcon -> focuses on -> titular ship
# Falcon -> is with -> Chewbacca as her co-pilot
# Chewbacca -> take possession after -> Solo 's hibernation by Empire
# Lando -> take possession after -> Solo 's hibernation in carbonite
# ship -> outrun Imperial TIE fighters during -> asteroid-field-escape scene
# 5,195-piece Lego model -> part of -> Star Wars Ultimate Collectors Series
# it -> has appeared in -> Return of Jedi
